# %%
import pandas as pd

# %%
df = pd.read_csv("E-commerce Customer_Behavior_Purchase_Dataset.csv")

# %%
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             44605  2023-05-03 21:30:02             Home            177
# 1             44605  2021-05-16 13:57:44      Electronics            174
# 2             44605  2020-07-13 06:16:57            Books            413
# 3             44605  2023-01-17 13:14:36      Electronics            396
# 4             44605  2021-05-01 11:29:27            Books            259
# ...             ...                  ...              ...            ...
# 249995        33807  2023-01-24 12:32:18             Home            436
# 249996        20455  2021-06-04 05:45:25      Electronics            233
# 249997        28055  2022-11-10 17:11:57      Electronics            441
# 249998        15023  2021-06-27 14:42:12      Electronics             44
# 249999         4148  2020-09-07 05:12:19             Home            307
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.shape
# Out:
# (250000, 13)

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47382
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %%
df.dtypes
# Out:
# Customer ID                int64
# Purchase Date             object
# Product Category          object
# Product Price              int64
# Quantity                   int64
# Total Purchase Amount      int64
# Payment Method            object
# Customer Age               int64
# Returns                  float64
# Customer Name             object
# Age                        int64
# Gender                    object
# Churn                      int64
# dtype: object

# %%
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             44605  2023-05-03 21:30:02             Home            177
# 1             44605  2021-05-16 13:57:44      Electronics            174
# 2             44605  2020-07-13 06:16:57            Books            413
# 3             44605  2023-01-17 13:14:36      Electronics            396
# 4             44605  2021-05-01 11:29:27            Books            259
# ...             ...                  ...              ...            ...
# 249995        33807  2023-01-24 12:32:18             Home            436
# 249996        20455  2021-06-04 05:45:25      Electronics            233
# 249997        28055  2022-11-10 17:11:57      Electronics            441
# 249998        15023  2021-06-27 14:42:12      Electronics             44
# 249999         4148  2020-09-07 05:12:19             Home            307
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.drop(columns=['Customer Name'])
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             44605  2023-05-03 21:30:02             Home            177
# 1             44605  2021-05-16 13:57:44      Electronics            174
# 2             44605  2020-07-13 06:16:57            Books            413
# 3             44605  2023-01-17 13:14:36      Electronics            396
# 4             44605  2021-05-01 11:29:27            Books            259
# ...             ...                  ...              ...            ...
# 249995        33807  2023-01-24 12:32:18             Home            436
# 249996        20455  2021-06-04 05:45:25      Electronics            233
# 249997        28055  2022-11-10 17:11:57      Electronics            441
# 249998        15023  2021-06-27 14:42:12      Electronics             44
# 249999         4148  2020-09-07 05:12:19             Home            307
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.drop(columns=['Churn'], inplace =True)

# %%
df.drop_duplicates()
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             44605  2023-05-03 21:30:02             Home            177
# 1             44605  2021-05-16 13:57:44      Electronics            174
# 2             44605  2020-07-13 06:16:57            Books            413
# 3             44605  2023-01-17 13:14:36      Electronics            396
# 4             44605  2021-05-01 11:29:27            Books            259
# ...             ...                  ...              ...            ...
# 249995        33807  2023-01-24 12:32:18             Home            436
# 249996        20455  2021-06-04 05:45:25      Electronics            233
# 249997        28055  2022-11-10 17:11:57      Electronics            441
# 249998        15023  2021-06-27 14:42:12      Electronics             44
# 249999         4148  2020-09-07 05:12:19             Home            307
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.dropna(subset=['Returns'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer ID              0
# Purchase Date            0
# Product Category         0
# Product Price            0
# Quantity                 0
# Total Purchase Amount    0
# Payment Method           0
# Customer Age             0
# Returns                  0
# Customer Name            0
# Age                      0
# Gender                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Customer ID                int64
# Purchase Date             object
# Product Category          object
# Product Price              int64
# Quantity                   int64
# Total Purchase Amount      int64
# Payment Method            object
# Customer Age               int64
# Returns                  float64
# Customer Name             object
# Age                        int64
# Gender                    object
# dtype: object

# %%
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             44605  2023-05-03 21:30:02             Home            177
# 1             44605  2021-05-16 13:57:44      Electronics            174
# 2             44605  2020-07-13 06:16:57            Books            413
# 3             44605  2023-01-17 13:14:36      Electronics            396
# 4             44605  2021-05-01 11:29:27            Books            259
# ...             ...                  ...              ...            ...
# 249994        39806  2021-08-01 04:43:12      Electronics            225
# 249995        33807  2023-01-24 12:32:18             Home            436
# 249996        20455  2021-06-04 05:45:25      Electronics            233
# 249998        15023  2021-06-27 14:42:12      Electronics             44
# 249999         4148  2020-09-07 05:12:19             Home            307
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age Returns  \
# ...

# %%
df.dtypes
# Out:
# Customer ID                       int64
# Purchase Date            datetime64[ns]
# Product Category                 object
# Product Price                     int64
# Quantity                          int64
# Total Purchase Amount             int64
# Payment Method                   object
# Customer Age                      int64
# Returns                         float64
# Customer Name                    object
# Age                               int64
# Gender                           object
# dtype: object

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])

# %%
df.dtypes
# Out:
# Customer ID                       int64
# Purchase Date            datetime64[ns]
# Product Category                 object
# Product Price                     int64
# Quantity                          int64
# Total Purchase Amount             int64
# Payment Method                   object
# Customer Age                      int64
# Returns                         float64
# Customer Name                    object
# Age                               int64
# Gender                           object
# dtype: object

# %%
df
# Out:
#         Customer ID       Purchase Date Product Category  Product Price  \
# 0             44605 2023-05-03 21:30:02             Home            177
# 1             44605 2021-05-16 13:57:44      Electronics            174
# 2             44605 2020-07-13 06:16:57            Books            413
# 3             44605 2023-01-17 13:14:36      Electronics            396
# 4             44605 2021-05-01 11:29:27            Books            259
# ...             ...                 ...              ...            ...
# 249994        39806 2021-08-01 04:43:12      Electronics            225
# 249995        33807 2023-01-24 12:32:18             Home            436
# 249996        20455 2021-06-04 05:45:25      Electronics            233
# 249998        15023 2021-06-27 14:42:12      Electronics             44
# 249999         4148 2020-09-07 05:12:19             Home            307
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df['Returns'] = df['Returns'].astype(str)

# %%
df['Returns'] = df['Returns'].str.replace(r'\..*', '', regex=True)

# %%
df['Returns'] = df['Returns'].astype(int)

# %%
df
# Out:
#         Customer ID       Purchase Date Product Category  Product Price  \
# 0             44605 2023-05-03 21:30:02             Home            177
# 1             44605 2021-05-16 13:57:44      Electronics            174
# 2             44605 2020-07-13 06:16:57            Books            413
# 3             44605 2023-01-17 13:14:36      Electronics            396
# 4             44605 2021-05-01 11:29:27            Books            259
# ...             ...                 ...              ...            ...
# 249994        39806 2021-08-01 04:43:12      Electronics            225
# 249995        33807 2023-01-24 12:32:18             Home            436
# 249996        20455 2021-06-04 05:45:25      Electronics            233
# 249998        15023 2021-06-27 14:42:12      Electronics             44
# 249999         4148 2020-09-07 05:12:19             Home            307
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.to_csv(r'Clean_e-commerce Customer Behavior & Purchase Dataset.csv', index=False)
print("Dataset saved!")
# Out:
# Dataset saved!
